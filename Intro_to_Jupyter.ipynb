# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # Introduction to Jupyter Notebooks
#
# Jupyter Notebooks are interactive computing environments that allow you to combine **code execution**, **visualizations**, and **narrative text** in a single document. They are widely used for data analysis, machine learning, and research documentation.

# %%
2+2
# Out:
# 4

# %% [markdown]
# # My Learning Progress in Jupyter
# I have learned **Markdown basics** and *Python coding*.
#
# ## Key Topics Covered
# - Python basics
# - Data analysis
# - Visualization

# %% [markdown]
# ![Alt Text](https://upload.wikimedia.org/wikipedia/commons/3/38/Jupyter_logo.svg)

# %% [markdown]
# [Visit Python.org](https://www.python.org)

# %% [markdown]
# ## My Favorite Programming Languages
# 1. Python
# 2. JavaScript
# 3. C++
# 4. Java

# %%
# Function to calculate factorial
def factorial(n):
    if n < 0:
        return "Factorial not defined for negative numbers"
    elif n == 0 or n == 1:
        return 1
    return n*factorial(n-1)

# Testing the factorial function
print("Factorial of 0:", factorial(0))
print("Factorial of 5:", factorial(5))
print("Factorial of 7:", factorial(7))
# Out:
# Factorial of 0: 1
# Factorial of 5: 120
# Factorial of 7: 5040

# %%
import numpy as np


data = [10, 20, 30, 40, 50]

mean_value = np.mean(data)
median_value = np.median(data)

print("Mean:", mean_value)
print("Median:", median_value)
# Out:
# Mean: 30.0
# Median: 30.0

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Plot
plt.plot(x, y, marker='o', color='blue')
plt.title("Simple Line Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)
plt.show()

# %%
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt


df = pd.DataFrame({
    "X": [1, 2, 3, 4, 5],
    "Y": [2, 4, 6, 8, 10]
})


sns.set(style="darkgrid")


sns.lineplot(data=df, x="X", y="Y", marker="o", color="blue")


plt.title("Simple Line Plot (Seaborn)")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")


plt.show()

# %%
# Export to HTML
# Out:
#   Cell In[1], line 2
#     jupyter nbconvert --to html Intro_to_Jupyter.ipynb
#             ^
# SyntaxError: invalid syntax
